# %%
import numpy as np
import pandas as pd
import pygimli as pg
from pygimli.physics import ert
import matplotlib.pyplot as plt
import glob
import os
import matplotlib.patheffects as PathEffects

# %%
# figure plotting preferences 

dpi = 200 # resolution
fs = 20 # fontsize

# %%
# copy threshold values from profile with borehole

y_th_lamp = np.array(
[1321.4234194980504,
 872.6853829988842,
 721.1252041859406,
 1422.1631935223727,
 667.0783035113924,
 895.2164767611438,
 991.5619339262407]
)

# %%
# range of inversion parameters to test 

lam = np.array([1,3,9,
               3,3,
               3,3])

mstart_mult = np.array([1,1,1,
                  1,1,
                  0.1,10])

err_rel = np.array([0.03,0.03,0.03,
                    0.015,0.06,
                    0.03,0.03])

# %%
def invert_w_sensitivity(pn,fn,sensorids,yth,lam,mstart_mult,err_rel):
    
    T_plt_all = []
    R_plt_all = []
    p_f_all = []
    p_uf_all = []
    xth_all = []
    yth_all = []
    contours = []
    
    for j in range(0,len(lam)):
        
        contours_temp = []
        # load raw fata

        data_raw = ert.load(pn+fn) 

        survey_name=fn
        plotmodel=True

        # calculate geometric factor and apparent resistivity if not already in data file

        if data_raw.haveData('k')==False:
            data_raw['k'] = ert.createGeometricFactors(data_raw,numerical=True) # include topo in k calculation

        if data_raw.haveData('rhoa')==False:
            if data_raw.haveData('r')==False:
                data_raw['r'] = data_raw['u']/data_raw['i']
            data_raw['rhoa'] = data_raw['r']*data_raw['k'] 

        # some datasets had problematic cables. if so, remove those data points

        if sensorids is not None:
            data_raw.removeSensorIdx(sensorids)

        mgr = ert.ERTManager(data_raw)

        # inversion parameters

        mgr.inv.inv.setBlockyModel(True)

        data_raw['err'] = ert.estimateError(
        data_raw, 
        absoluteError=0.001, 
        relativeError=err_rel[j] # % noise
        )

        # run inversion

        mod = mgr.invert(
            data_raw,
            lam=lam[j],
            startModel=np.mean(data_raw['rhoa'])*mstart_mult[j],
        )

        # getting chi2, rms error

        chi2 = mgr.inv.inv.getChi2()
        rms = np.sqrt(np.mean(((data_raw['rhoa']-mgr.inv.response)/data_raw['rhoa'])**2))*100

        # plot results

        fig1, ax1 = plt.subplots(1,1,figsize=[13,5])

        ax, cBar = mgr.showResult(
           mod,
            ax=ax1,
            cMap='turbo_r',
            coverage=mgr.coverage(),
            cMin=100,
            cMax=15000,
            orientation='vertical',
        )

        # colorbar

        cBar.set_label('')
        cBar.ax.tick_params(labelsize=fs-4) 
        cBar.ax.set_title(r'$\rho$ ($\Omega$m)'+ '\n',fontsize=fs,rotation=270, y=0.35,x=5)

        # get axis limits and trim figure automatically

        Ex = np.array(data_raw.sensors()).T[0]
        Ey = np.array(data_raw.sensors()).T[1]
        xmin = min(Ex)
        xmax = max(Ex)
        ymin = mgr.paraDomain.yMin()
        ymax = mgr.paraDomain.yMax()
        trim_ymin = ymin + (ymax-ymin)/3
        ax1.set_ylim([trim_ymin,ymax+abs(ymax-ymin)*0.07])
        ax1.set_xlim([xmin,xmax])

        # figure details - electrodes, rms error, axis labels, borehole location

#         ax1.plot(Ex,Ey,'ko')
        txt = ax1.text(xmin+(xmax-xmin)*0.02,trim_ymin+(ymax-trim_ymin)*0.1,'RMSE=%.1f%%'%(rms),color='k',fontsize=fs)
        ax1.tick_params(axis='both', labelsize=fs-4)
        ax1.set_xlabel('X (m)',fontsize=fs)
        ax1.set_ylabel('Z (m)',fontsize=fs)
        
        if j==1: # best estimate model
            
            cs = ax1.tricontour(
                np.array(mgr.paraDomain.cellCenters()).T[0],
                np.array(mgr.paraDomain.cellCenters()).T[1],
                mgr.model,
                levels=[yth[j]],
                colors='k',
                linewidth=3,
                alpha=1,
                zorder=3          
                  )   

        else: # sensitivity analyis results

            cs = ax1.tricontour(
                np.array(mgr.paraDomain.cellCenters()).T[0],
                np.array(mgr.paraDomain.cellCenters()).T[1],
                mgr.model,
                levels=[yth[j]],
                colors='blueviolet',
                linewidth=3,
                alpha=1,
                  ) 

        for collection in cs.collections:
            for path in collection.get_paths():
                contours_temp.append(path.vertices.copy())      

        contours.append(contours_temp)
        
        plt.show()     
    return contours

# %%
contours_lamp = invert_w_sensitivity(
    pn = '.formatted ert data/summer 2023/',
    fn = '20230829 LAMP2 W160.txt',
    sensorids = None,
    yth=y_th_lamp,
    lam=lam,
    mstart_mult= mstart_mult,
    err_rel=err_rel
)
# Out:
# 26/11/25 - 16:07:09 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 52): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:07:09 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:07:09 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:07:09 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:07:09 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:07:09 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:07:09 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:07:09 - pyGIMLi - INFO - Homogeneous starting model set to: 2627.3123000653964
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:07:20 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 53): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:07:20 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:07:20 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:07:20 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:07:20 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:07:20 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:07:20 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:07:20 - pyGIMLi - INFO - Homogeneous starting model set to: 2627.3123000653964
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:110: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:07:29 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 54): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:07:29 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:07:29 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:07:29 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:07:29 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:07:29 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:07:29 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:07:29 - pyGIMLi - INFO - Homogeneous starting model set to: 2627.3123000653964
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:07:39 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 55): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:07:39 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:07:39 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:07:39 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:07:39 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:07:39 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:07:39 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:07:39 - pyGIMLi - INFO - Homogeneous starting model set to: 2627.3123000653964
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:07:49 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 56): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:07:49 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:07:49 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:07:49 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:07:49 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:07:49 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:07:49 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:07:49 - pyGIMLi - INFO - Homogeneous starting model set to: 2627.3123000653964
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:110: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:07:58 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 57): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:07:58 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:07:58 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:07:58 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:07:58 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:07:58 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:07:58 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:07:58 - pyGIMLi - INFO - Homogeneous starting model set to: 2627.3123000653964
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:08:05 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 58): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:08:05 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:05 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:05 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:05 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:05 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:05 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:05 - pyGIMLi - INFO - Homogeneous starting model set to: 262.73123000653965
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:08:13 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 59): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:08:13 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:13 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:13 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:13 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:13 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:13 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:13 - pyGIMLi - INFO - Homogeneous starting model set to: 2627.3123000653964
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:110: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:08:21 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 60): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:08:21 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:21 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:21 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:21 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:21 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:21 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:21 - pyGIMLi - INFO - Homogeneous starting model set to: 26273.123000653963
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_61758/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(

# %%
  
j=1

pn = 'formatted ert data/summer 2023/'
fn = '20230829 LAMP2 W160.txt'

sensorids = None

data_raw = ert.load(pn+fn) 

# calculate geometric factor and apparent resistivity if not already in data file

if data_raw.haveData('k')==False:
    data_raw['k'] = ert.createGeometricFactors(data_raw,numerical=True) # include topo in k calculation

if data_raw.haveData('rhoa')==False:
    if data_raw.haveData('r')==False:
        data_raw['r'] = data_raw['u']/data_raw['i']
    data_raw['rhoa'] = data_raw['r']*data_raw['k'] 

# some datasets had problematic cables. if so, remove those data points

if sensorids is not None:
    data_raw.removeSensorIdx(sensorids)

mgr = ert.ERTManager(data_raw)

# inversion parameters

mgr.inv.inv.setBlockyModel(True)

data_raw['err'] = ert.estimateError(
data_raw, 
absoluteError=0.001, 
relativeError=err_rel[j] # % noise
)

# run inversion

mod = mgr.invert(
    data_raw,
    lam=lam[j],
    startModel=np.mean(data_raw['rhoa'])*mstart_mult[j],
#             zWeight=0.5
#             area=2,
#             verbose=True
)

# getting chi2, rms error

chi2 = mgr.inv.inv.getChi2()
rms = np.sqrt(np.mean(((data_raw['rhoa']-mgr.inv.response)/data_raw['rhoa'])**2))*100
# Out:
# 26/11/25 - 16:08:30 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.9s x 61): /Users/teddiherringnew/Library/Caches/pygimli/4685734810500315786
# 26/11/25 - 16:08:31 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:31 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:31 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:31 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:31 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:31 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:31 - pyGIMLi - INFO - Homogeneous starting model set to: 2627.3123000653964

# %%
# plot results

fig1, ax1 = plt.subplots(1,1,figsize=[15,5])

ax, cBar = mgr.showResult(
   mod,
    ax=ax1,
    cMap='turbo_r',
    coverage=mgr.coverage(),
    cMin=100,
    cMax=15000,
    orientation='vertical',
)

# colorbar

cBar.set_label('')
cBar.ax.tick_params(labelsize=fs-4) 
# cBar.ax.set_title(r'$\rho$ ($\Omega$m)'+ '\n',fontsize=fs,rotation=270, y=0.35,x=5)
cBar.ax.set_title(r'Resistivity ($\Omega$m)'+ '\n',fontsize=fs,rotation=270, y=-0.06,x=5)

# get axis limits and trim figure automatically

Ex = np.array(data_raw.sensors()).T[0]
Ey = np.array(data_raw.sensors()).T[1]
xmin = min(Ex)
xmax = max(Ex)
ymin = mgr.paraDomain.yMin()
ymax = mgr.paraDomain.yMax()
trim_ymin = ymin + (ymax-ymin)/2
ax1.set_ylim([trim_ymin,ymax+abs(ymax-ymin)*0.07])
ax1.set_xlim([xmin,xmax])

# figure details - electrodes, rms error, axis labels, borehole location

# ax1.plot(Ex,Ey,'ko')
txt = ax1.text(xmin+(xmax-xmin)*0.02,trim_ymin+(ymax-trim_ymin)*0.1,'RMSE=%.1f%%'%(rms),color='k',fontsize=fs)
#         txt.set_path_effects([PathEffects.withStroke(linewidth=3, foreground='k')])
ax1.tick_params(axis='both', labelsize=fs-4)
ax1.set_xlabel('X (m)',fontsize=fs)
ax1.set_ylabel('Z (m)',fontsize=fs)
# ax1.plot([x_bh,x_bh],[Ey[Ex==x_bh]-depth_bh,Ey[Ex==x_bh]],color='w',linewidth=5)


for i in range(len(contours_lamp)):
# for i in range(2,3):
    for j in range(len(contours_lamp[i])):
        if i in [1, 4, 7]:
            ax1.plot(contours_lamp[i][j][:, 0],contours_lamp[i][j][:, 1], color='k',linestyle='-',linewidth=3,alpha=1,zorder=3)
        else:
            ax1.plot(contours_lamp[i][j][:, 0],contours_lamp[i][j][:, 1], color='blueviolet',linestyle='-',linewidth=3,alpha=0.6,zorder=2)



# for k in range(20,len(ft_x)):
#     ax1.plot(ft_x[k],Ey[np.where(Ex==ft_x[k])[0]]-ft_z[k]/100,marker='.',color='deepskyblue',markersize=8,zorder=4)
#     ax1.plot(ft_x[k],Ey[np.where(Ex==ft_x[k])[0]]-ft_z[k]/100,marker='.',color='k',markersize=12,zorder=3)

          
frost_table = pd.read_excel('/Users/teddiherringnew/Desktop/HBR_ERT_JGR/frost tables/20230829 LAMP 160.xlsx')   
ft_x = np.array(frost_table['x'])
topo_x = np.array(data_raw.sensors()).T[0]

ft_z = np.array(frost_table['z'])
topo_z = np.array(data_raw.sensors()).T[1]

ft_z = np.where(ft_z==0, np.nan, ft_z) 

ax1 = fig1.add_axes([0.125,0.83,0.755,0.28])
[x,i1,i2] = np.intersect1d(ft_x,topo_x,return_indices=True)
ax1.plot(ft_x,ft_z/100,'ko-')
ax1.set_ylabel('Frost table (m)',fontsize=fs)
plt.gca().invert_yaxis()
ax1.set_xlim([xmin,xmax])
ax1.tick_params(axis='both', labelsize=fs-4)
ax1.tick_params(labelbottom=False)    
ax1.set_ylim([0.8,0.3])
ax1.set_yticks(np.arange(0.3,.81,step=0.1)) 
                
            
fig1.savefig('inverted results/lamprey uncertainty/summary_ft.png',format='png',dpi=dpi,bbox_inches='tight',facecolor='w')

ax.axhline(y=35, color='red',zorder=6)

# %%
# lamp


zmin = 20
zmax=35

I2 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[1]<zmax,
    np.array(mgr.paraDomain.cellCenters()).T[1]>zmin
)




print('no peat')

I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>0,
    np.array(mgr.paraDomain.cellCenters()).T[0]<8,
)

I3 = np.logical_and(I1,I2)

print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print(np.mean(np.array(mod)[I3]))

print('')


I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>32,
    np.array(mgr.paraDomain.cellCenters()).T[0]<80,
)

I3 = np.logical_and(I1,I2)

print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print(np.mean(np.array(mod)[I3]))

print('')



I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>104,
    np.array(mgr.paraDomain.cellCenters()).T[0]<136,
)

I3 = np.logical_and(I1,I2)

print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print(np.mean(np.array(mod)[I3]))

print('')
# Out:
# no peat
# 827.4022984244276
# 4036.4904782619906
# 2341.4053320321123
#
# 1254.7353463324728
# 11395.462409189053
# 4212.756578597496
#
# 1396.7250923713116
# 16468.271580558798
# 6961.73062361894

# %%
print('peat')

I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>8,
    np.array(mgr.paraDomain.cellCenters()).T[0]<32,
)


I3 = np.logical_and(I1,I2)

print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print(np.mean(np.array(mod)[I3]))

print('')


I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>80,
    np.array(mgr.paraDomain.cellCenters()).T[0]<104,
)

I3 = np.logical_and(I1,I2)

print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print(np.mean(np.array(mod)[I3]))

print('')



I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>136,
    np.array(mgr.paraDomain.cellCenters()).T[0]<160,
)


I3 = np.logical_and(I1,I2)

print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print(np.mean(np.array(mod)[I3]))

print('')
# Out:
# peat
# 2067.278298599689
# 8373.685199311789
# 4258.362288068219
#
# 2800.877315061425
# 19181.874426385773
# 8603.340299390364
#
# 5148.249866916926
# 15767.208545967507
# 12115.770961543345
