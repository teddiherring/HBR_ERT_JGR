# %%
import numpy as np
import pandas as pd
import pygimli as pg
from pygimli.physics import ert
import matplotlib.pyplot as plt
import glob
import os
import matplotlib.patheffects as PathEffects

# %%
# figure plotting preferences 

dpi = 200 # resolution
fs = 20 # fontsize

# %%
y_th_ches = np.array(
    [928.0927430071451,
 854.7742163792061,
 890.7924948926072,
 582.039967740979,
 854.7742163792061,
 826.4590065970598,
 869.3546281139518,
854.7742163792061,
889.5705980852852])

# %%
lam = np.array([1,3,9,
               3,3,3,
               3,3,3])

mstart_mult = np.array([1,1,1,
                  1,1,1,
                  0.1,1,10])

err_rel = np.array([0.03,0.03,0.03,
                    0.015,0.03,0.06,
                    0.03,0.03,0.03])

# %%
def invert_w_sensitivity(pn,fn,sensorids,yth,lam,mstart_mult,err_rel):
    
    T_plt_all = []
    R_plt_all = []
    p_f_all = []
    p_uf_all = []
    xth_all = []
    yth_all = []
    contours = []
    
    for j in range(0,len(lam)):
#     for j in range(0,1):
        
        contours_temp = []
        # load raw fata

        data_raw = ert.load(pn+fn) 

        survey_name=fn
        plotmodel=True

        # calculate geometric factor and apparent resistivity if not already in data file

        if data_raw.haveData('k')==False:
            data_raw['k'] = ert.createGeometricFactors(data_raw,numerical=True) # include topo in k calculation

        if data_raw.haveData('rhoa')==False:
            if data_raw.haveData('r')==False:
                data_raw['r'] = data_raw['u']/data_raw['i']
            data_raw['rhoa'] = data_raw['r']*data_raw['k'] 

        # some datasets had problematic cables. if so, remove those data points

        if sensorids is not None:
            data_raw.removeSensorIdx(sensorids)

        mgr = ert.ERTManager(data_raw)

        # inversion parameters

        mgr.inv.inv.setBlockyModel(True)

        data_raw['err'] = ert.estimateError(
        data_raw, 
        absoluteError=0.001, 
        relativeError=err_rel[j] # % noise
        )

        # run inversion

        mod = mgr.invert(
            data_raw,
            lam=lam[j],
            startModel=np.mean(data_raw['rhoa'])*mstart_mult[j],
#             area=2,
#             verbose=True
        )

        # getting chi2, rms error

        chi2 = mgr.inv.inv.getChi2()
        rms = np.sqrt(np.mean(((data_raw['rhoa']-mgr.inv.response)/data_raw['rhoa'])**2))*100

        # plot results

        fig1, ax1 = plt.subplots(1,1,figsize=[13,5])

        ax, cBar = mgr.showResult(
           mod,
            ax=ax1,
            cMap='turbo_r',
            coverage=mgr.coverage(),
            cMin=100,
            cMax=15000,
            orientation='vertical',
        )

        # colorbar

        cBar.set_label('')
        cBar.ax.tick_params(labelsize=fs-4) 
        cBar.ax.set_title(r'$\rho$ ($\Omega$m)'+ '\n',fontsize=fs,rotation=270, y=0.35,x=5)

        # get axis limits and trim figure automatically

        Ex = np.array(data_raw.sensors()).T[0]
        Ey = np.array(data_raw.sensors()).T[1]
        xmin = min(Ex)
        xmax = max(Ex)
        ymin = mgr.paraDomain.yMin()
        ymax = mgr.paraDomain.yMax()
        trim_ymin = ymin + (ymax-ymin)/3
        ax1.set_ylim([trim_ymin,ymax+abs(ymax-ymin)*0.07])
        ax1.set_xlim([xmin,xmax])

        # figure details - electrodes, rms error, axis labels, borehole location

        ax1.plot(Ex,Ey,'ko')
        txt = ax1.text(xmin+(xmax-xmin)*0.02,trim_ymin+(ymax-trim_ymin)*0.1,'RMSE=%.1f%%'%(rms),color='k',fontsize=fs)
#         txt.set_path_effects([PathEffects.withStroke(linewidth=3, foreground='k')])
        ax1.tick_params(axis='both', labelsize=fs-4)
        ax1.set_xlabel('X (m)',fontsize=fs)
        ax1.set_ylabel('Z (m)',fontsize=fs)
#         ax1.plot([x_bh,x_bh],[Ey[Ex==x_bh]-depth_bh,Ey[Ex==x_bh]],color='k',linewidth=4)
      
        
        if j in [1, 4, 7]:


            cs = ax1.tricontour(
                np.array(mgr.paraDomain.cellCenters()).T[0],
                np.array(mgr.paraDomain.cellCenters()).T[1],
                mgr.model,
                levels=[yth[j]],
                colors='k',
                linewidth=3,
                alpha=1,
                zorder=3          
                  )   

        else:

            cs = ax1.tricontour(
                np.array(mgr.paraDomain.cellCenters()).T[0],
                np.array(mgr.paraDomain.cellCenters()).T[1],
                mgr.model,
                levels=[yth[j]],
                colors='blueviolet',
                linewidth=3,
                alpha=1,
                  ) 


#         for i, collection in enumerate(cs.collections):
#             paths = collection.get_paths()
#             for path in paths:
#                 v = path.vertices
#                 contours.append(v)   # each v is an (N, 2) array of x,y points
                
        for collection in cs.collections:
            for path in collection.get_paths():
                contours_temp.append(path.vertices.copy())      

#         plt.close(fig1)

        contours.append(contours_temp)
        
        plt.show()     
    return contours

# %%
contours_ches = invert_w_sensitivity(
    pn = 'formatted ert data/summer 2023/',
    fn = '20230901 CHES W200.txt',
    sensorids = None,
    yth=y_th_ches,
    lam=lam,
    mstart_mult=mstart_mult,
    err_rel=err_rel
)
# Out:
# 26/11/25 - 16:08:23 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 23): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:08:23 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:23 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:23 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:23 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:23 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:23 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:23 - pyGIMLi - INFO - Homogeneous starting model set to: 384.11857156459337
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:08:32 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 24): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:08:32 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:32 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:32 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:32 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:32 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:32 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:32 - pyGIMLi - INFO - Homogeneous starting model set to: 384.11857156459337
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:110: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:08:38 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 25): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:08:38 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:38 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:38 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:38 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:38 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:38 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:38 - pyGIMLi - INFO - Homogeneous starting model set to: 384.11857156459337
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:08:43 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 26): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:08:43 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:43 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:43 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:43 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:43 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:43 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:43 - pyGIMLi - INFO - Homogeneous starting model set to: 384.11857156459337
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:08:50 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 27): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:08:50 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:50 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:50 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:50 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:50 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:50 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:50 - pyGIMLi - INFO - Homogeneous starting model set to: 384.11857156459337
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:110: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:08:56 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 28): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:08:56 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:08:56 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:08:56 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:08:56 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:08:56 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:08:56 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:08:56 - pyGIMLi - INFO - Homogeneous starting model set to: 384.11857156459337
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:09:00 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 29): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:09:00 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:09:00 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:09:00 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:09:00 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:09:00 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:09:00 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:09:00 - pyGIMLi - INFO - Homogeneous starting model set to: 38.41185715645934
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:09:05 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 30): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:09:05 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:09:05 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:09:05 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:09:05 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:09:05 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:09:05 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:09:05 - pyGIMLi - INFO - Homogeneous starting model set to: 384.11857156459337
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:110: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 26/11/25 - 16:09:11 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 31): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:09:11 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:09:11 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:09:11 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:09:11 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:09:11 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:09:11 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:09:11 - pyGIMLi - INFO - Homogeneous starting model set to: 3841.1857156459337
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_72794/2248237447.py:123: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(

# %%
 
j=1
pn = 'formatted ert data/summer 2023/'
fn = '20230901 CHES W200.txt'
sensorids = None

data_raw = ert.load(pn+fn) 

# calculate geometric factor and apparent resistivity if not already in data file

if data_raw.haveData('k')==False:
    data_raw['k'] = ert.createGeometricFactors(data_raw,numerical=True) # include topo in k calculation

if data_raw.haveData('rhoa')==False:
    if data_raw.haveData('r')==False:
        data_raw['r'] = data_raw['u']/data_raw['i']
    data_raw['rhoa'] = data_raw['r']*data_raw['k'] 

# some datasets had problematic cables. if so, remove those data points

if sensorids is not None:
    data_raw.removeSensorIdx(sensorids)

mgr = ert.ERTManager(data_raw)

# inversion parameters

# mgr.inv.inv.setBlockyModel(True)

data_raw['err'] = ert.estimateError(
data_raw, 
absoluteError=0.001, 
relativeError=err_rel[j] # % noise
)

# run inversion

mod = mgr.invert(
    data_raw,
    lam=lam[j],
    startModel=np.mean(data_raw['rhoa'])*mstart_mult[j],
#             zWeight=0.5
#             area=2,
#             verbose=True
)

# getting chi2, rms error

chi2 = mgr.inv.inv.getChi2()
rms = np.sqrt(np.mean(((data_raw['rhoa']-mgr.inv.response)/data_raw['rhoa'])**2))*100
# Out:
# 26/11/25 - 16:09:17 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (1.8s x 32): /Users/teddiherringnew/Library/Caches/pygimli/3295802236228985221
# 26/11/25 - 16:09:17 - pyGIMLi - INFO - Found 2 regions.
# 26/11/25 - 16:09:17 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 26/11/25 - 16:09:17 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 26/11/25 - 16:09:17 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 26/11/25 - 16:09:17 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/11/25 - 16:09:17 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/11/25 - 16:09:17 - pyGIMLi - INFO - Homogeneous starting model set to: 384.11857156459337

# %%
# plot results

fig1, ax1 = plt.subplots(1,1,figsize=[15,5])

ax, cBar = mgr.showResult(
   mod,
    ax=ax1,
    cMap='turbo_r',
    coverage=mgr.coverage(),
    cMin=100,
    cMax=15000,
    orientation='vertical',
)

# colorbar

cBar.set_label('')
cBar.ax.tick_params(labelsize=fs-4) 
cBar.ax.set_title(r'Resistivity ($\Omega$m)'+ '\n',fontsize=fs,rotation=270, y=-0.06,x=5)

# get axis limits and trim figure automatically

Ex = np.array(data_raw.sensors()).T[0]
Ey = np.array(data_raw.sensors()).T[1]
xmin = min(Ex)
xmax = max(Ex)
ymin = mgr.paraDomain.yMin()
ymax = mgr.paraDomain.yMax()
trim_ymin = ymin + (ymax-ymin)/2
ax1.set_ylim([trim_ymin,ymax+abs(ymax-ymin)*0.07])
ax1.set_xlim([xmin,xmax])

# figure details - electrodes, rms error, axis labels, borehole location

# ax1.plot(Ex,Ey,'ko')
txt = ax1.text(xmin+(xmax-xmin)*0.2,trim_ymin+(ymax-trim_ymin)*0.1,'RMSE=%.1f%%'%(rms),color='k',fontsize=fs)
#         txt.set_path_effects([PathEffects.withStroke(linewidth=3, foreground='k')])
ax1.tick_params(axis='both', labelsize=fs-4)
ax1.set_xlabel('X (m)',fontsize=fs)
ax1.set_ylabel('Z (m)',fontsize=fs)
# ax1.plot([x_bh,x_bh],[Ey[Ex==x_bh]-depth_bh,Ey[Ex==x_bh]],color='w',linewidth=5)


for i in range(len(contours_ches)):
# for i in range(2,3):
    for j in range(len(contours_ches[i])):
        if i in [1, 4, 7]:
            ax1.plot(contours_ches[i][j][:, 0],contours_ches[i][j][:, 1], color='k',linestyle='-',linewidth=3,alpha=1,zorder=3)
        else:
            ax1.plot(contours_ches[i][j][:, 0],contours_ches[i][j][:, 1], color='blueviolet',linestyle='-',linewidth=3,alpha=0.6,zorder=2)



# for k in range(20,len(ft_x)):
#     ax1.plot(ft_x[k],Ey[np.where(Ex==ft_x[k])[0]]-ft_z[k]/100,marker='.',color='deepskyblue',markersize=8,zorder=4)
#     ax1.plot(ft_x[k],Ey[np.where(Ex==ft_x[k])[0]]-ft_z[k]/100,marker='.',color='k',markersize=12,zorder=3)

            
xt = np.hstack([10,Ex,400])
yt = np.hstack([60,Ey+0.2,60])
from matplotlib.patches import Polygon

P= Polygon(np.array([xt,yt]).T, facecolor = 'w',edgecolor='w',linewidth=1,zorder=4) 
ax1.add_patch(P)


frost_table = pd.read_excel('/Users/teddiherringnew/Desktop/HBR_ERT_JGR/frost tables/20230901 CHES 200.xlsx')   
ft_x = np.array(frost_table['x'])
topo_x = np.array(data_raw.sensors()).T[0]

ft_z = np.array(frost_table['z'])
topo_z = np.array(data_raw.sensors()).T[1]

ft_z = np.where(ft_z==0, np.nan, ft_z) 

ax1 = fig1.add_axes([0.125,0.83,0.755,0.28])
[x,i1,i2] = np.intersect1d(ft_x,topo_x,return_indices=True)
ax1.plot(ft_x,ft_z/100,'ko-')
ax1.set_ylabel('Frost table (m)',fontsize=fs)
plt.gca().invert_yaxis()
ax1.set_xlim([xmin,xmax])
ax1.tick_params(axis='both', labelsize=fs-4)
ax1.tick_params(labelbottom=False)    
ax1.set_ylim([0.8,0.3])
ax1.set_yticks(np.arange(0.3,.81,step=0.1)) 

fig1.savefig('inverted results/ches uncertainty/summary_ft.png',format='png',dpi=dpi,bbox_inches='tight',facecolor='w')


# ytop = 60
# ymid = 50
# ybot = 30

# xleft = 50
# xmid1 = 85
# xmid2 = 145
# xright = 200

# ax.axhline(y=ytop, color='red',zorder=6)
# ax.axhline(y=ymid, color='red',zorder=6)
# ax.axhline(y=ybot, color='red',zorder=6)

# ax.axvline(x=xleft, color='red',zorder=6)
# ax.axvline(x=xmid1, color='red',zorder=6)
# ax.axvline(x=xmid2, color='red',zorder=6)
# ax.axvline(x=xright, color='red',zorder=6)

# %%
# ches lake

I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>50,
    np.array(mgr.paraDomain.cellCenters()).T[0]<200,
)

I2 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[1]<50,
    np.array(mgr.paraDomain.cellCenters()).T[1]>30
)

I3 = np.logical_and(I1,I2)

print('lower depths')
print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print('')


# ches lake

I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>50,
    np.array(mgr.paraDomain.cellCenters()).T[0]<85,
)

I2 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[1]<60,
    np.array(mgr.paraDomain.cellCenters()).T[1]>50
)

I3 = np.logical_and(I1,I2)

print('shallower depths, left lake ')
print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print('')

# ches lake

I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>85,
    np.array(mgr.paraDomain.cellCenters()).T[0]<145,
)

I2 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[1]<60,
    np.array(mgr.paraDomain.cellCenters()).T[1]>50
)

I3 = np.logical_and(I1,I2)

print('shallower depths, middle lake ')
print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print(np.mean(np.array(mod)[I3]))
print('')
plt.hist(np.array(mod)[I3])
print(np.sort(np.array(mod)[I3]))
# ches lake

I1 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[0]>145,
    np.array(mgr.paraDomain.cellCenters()).T[0]<200,
)

I2 = np.logical_and(
    np.array(mgr.paraDomain.cellCenters()).T[1]<60,
    np.array(mgr.paraDomain.cellCenters()).T[1]>50
)

I3 = np.logical_and(I1,I2)

print('shallower depths, right lake')
print(min(np.array(mod)[I3]))
print(max(np.array(mod)[I3]))
print('')
# Out:
# lower depths
# 15.496116792793158
# 286.1306656402179
#
# shallower depths, left lake
# 23.97118603210493
# 141.3224994552405
#
# shallower depths, middle lake
# 34.874463062604995
