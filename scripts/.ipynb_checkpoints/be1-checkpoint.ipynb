# %%
import numpy as np
import pandas as pd
import pygimli as pg
from pygimli.physics import ert
import matplotlib.pyplot as plt
import glob
import os
import matplotlib.patheffects as PathEffects

# %%
# figure plotting preferences 

dpi = 200 # resolution
fs = 20 # fontsize

# %%
# range of inversion parameters to test 

lam = np.array([1,3,9,
               3,3,3,
               3,3,3])

mstart_mult = np.array([1,1,1,
                  1,1,1,
                  0.1,1,10])

err_rel = np.array([0.03,0.03,0.03,
                    0.015,0.03,0.06,
                    0.03,0.03,0.03])

# %%
def generate_rho_T(pn,fn,pn_bh,x_bh,depth_bh,sensorids,lam,mstart_mult,err_rel):
    

    T_plt_all = []
    R_plt_all = []
    p_f_all = []
    p_uf_all = []
    xth_all = []
    yth_all = []
    contours = []
    
    for j in range(0,len(lam)):
#     for j in range(3,4):
        
        contours_temp = []
        # load raw fata

        data_raw = ert.load(pn+fn) 

        survey_name=fn
        plotmodel=True

        # calculate geometric factor and apparent resistivity if not already in data file

        if data_raw.haveData('k')==False:
            data_raw['k'] = ert.createGeometricFactors(data_raw,numerical=True) # include topo in k calculation

        if data_raw.haveData('rhoa')==False:
            if data_raw.haveData('r')==False:
                data_raw['r'] = data_raw['u']/data_raw['i']
            data_raw['rhoa'] = data_raw['r']*data_raw['k'] 

        # some datasets had problematic cables. if so, remove those data points

        if sensorids is not None:
            data_raw.removeSensorIdx(sensorids)

        mgr = ert.ERTManager(data_raw)

        # inversion parameters

        mgr.inv.inv.setBlockyModel(True)

        data_raw['err'] = ert.estimateError(
        data_raw, 
        absoluteError=0.001, 
        relativeError=err_rel[j] # % noise
        )

        # run inversion

        mod = mgr.invert(
            data_raw,
            lam=lam[j],
            startModel=np.mean(data_raw['rhoa'])*mstart_mult[j],
#             zWeight=0.5
#             area=2,
#             verbose=True
        )

        # getting chi2, rms error

        chi2 = mgr.inv.inv.getChi2()
        rms = np.sqrt(np.mean(((data_raw['rhoa']-mgr.inv.response)/data_raw['rhoa'])**2))*100

        # plot results

        fig1, ax1 = plt.subplots(1,1,figsize=[13,5])

        ax, cBar = mgr.showResult(
           mod,
            ax=ax1,
            cMap='turbo_r',
            coverage=mgr.coverage(),
            cMin=100,
            cMax=15000,
            orientation='vertical',
        )

        # colorbar

        cBar.set_label('')
        cBar.ax.tick_params(labelsize=fs-4) 
        cBar.ax.set_title(r'$\rho$ ($\Omega$m)'+ '\n',fontsize=fs,rotation=270, y=0.35,x=5)

        # get axis limits and trim figure automatically

        Ex = np.array(data_raw.sensors()).T[0]
        Ey = np.array(data_raw.sensors()).T[1]
        xmin = min(Ex)
        xmax = max(Ex)
        ymin = mgr.paraDomain.yMin()
        ymax = mgr.paraDomain.yMax()
        trim_ymin = ymin + (ymax-ymin)/3
        ax1.set_ylim([trim_ymin,ymax+abs(ymax-ymin)*0.07])
        ax1.set_xlim([xmin,xmax])

        # figure details - electrodes, rms error, axis labels, borehole location

#         ax1.plot(Ex,Ey,'ko')
        txt = ax1.text(xmin+(xmax-xmin)*0.02,trim_ymin+(ymax-trim_ymin)*0.1,'RMSE=%.1f%%'%(rms),color='k',fontsize=fs)
#         txt2 = ax1.text(xmin+(xmax-xmin)*0.02,trim_ymin+(ymax-trim_ymin)*0.25,r'$\chi^2$=%.1f'%(chi2),color='k',fontsize=fs)
        #         txt.set_path_effects([PathEffects.withStroke(linewidth=3, foreground='k')])
        ax1.tick_params(axis='both', labelsize=fs-4)
        ax1.set_xlabel('X (m)',fontsize=fs)
        ax1.set_ylabel('Z (m)',fontsize=fs)
        ax1.plot([x_bh,x_bh],[Ey[Ex==x_bh]-depth_bh,Ey[Ex==x_bh]],color='w',linewidth=5,zorder=4)

        # calculate coverage filter from sensitivity (using pygimli script)

        def addCoverageAlpha(coverage, dropThreshold=0.4):

            C = np.asarray(coverage)
            C = C[~np.isnan(C)]
            #    print(np.min(C), np.max(C))

            if (np.min(C) < 0.) | (np.max(C) > 1.) | (np.max(C) < 0.5):

                nn, hh = np.histogram(C, 50)
                nnn = nn.cumsum(axis=0) / float(len(C))

                #        print("min-max nnn ", min(nnn), max(nnn))
                mi = hh[np.min(np.where(nnn > 0.02)[0])]

                if np.min(nnn) > dropThreshold:
                    ma = np.max(C)
                else:
                    ma = hh[np.max(np.where(nnn < dropThreshold)[0])]
        #            mi = hh[min(np.where(nnn > 0.2)[0])]
        #            ma = hh[max(np.where(nnn < 0.7)[0])]

                C = (C - mi) / (ma - mi)
                C[np.where(C < 0.)] = 0.0
                C[np.where(C > 0.95)] = 1.0

            return(C)

        # interpolate results onto regular grid

        E = np.array(data_raw.sensors()).T[0]

        # get values from triangular mesh 

        Xm = np.array(mgr.paraDomain.cellCenters()).T[0]
        Ym = np.array(mgr.paraDomain.cellCenters()).T[1]
        Rm = np.array(mod)

        # make new grid

        xg = np.arange(min(E),max(E)+0.001,min(np.diff(E))/2)
        yg = np.arange(np.round(min(Ym),1),np.round(max(Ym),1)+0.1,0.1)
        [Xg,Yg]=np.meshgrid(xg,yg)

        # interpolate resistivity and coverage onto new grid

        from scipy.interpolate import griddata
        Cov = addCoverageAlpha(mgr.coverage())
        Rg = griddata(np.array( (Xm.flatten(), Ym.flatten()) ).T, Rm.flatten(), np.array((Xg.flatten(), Yg.flatten()) ).T,  method='linear')
        Cg = griddata(np.array( (Xm.flatten(), Ym.flatten()) ).T, Cov.flatten(), np.array((Xg.flatten(), Yg.flatten()) ).T,  method='linear')

        # load borehole data

        data_bh = pd.read_excel(pn_bh)

        z_bh = np.array(data_bh.keys())
        T_bh = data_bh.iloc[0].values

        # find resistivity at borehole loc

        Rhog = np.reshape(Rg,np.shape(Xg))

        y_corr = Yg.T[0]- Ey[np.where(Ex==x_bh)][0] # borehole depth -> elevation
        Rho_bh = Rhog[np.where(Xg==x_bh)]

        R_atT = []

        for i in range(len(z_bh)):
            R_atT.append(Rho_bh[np.where(abs(y_corr-z_bh[i])==min(abs(y_corr-z_bh[i])))[0][0]])

        R_atT = np.array(R_atT)

        R_plt = R_atT[~np.isnan(R_atT)]
        z_plt = z_bh[~np.isnan(R_atT)]
        T_plt = T_bh[~np.isnan(R_atT)]

        # plot temperature resistivity curve

        cmap = plt.get_cmap('rainbow', len(T_plt))

        fig2, ax2 = plt.subplots(1,1,figsize=[6,5])

        for i in range (len(T_plt)):
            plt.scatter(T_plt[i], R_plt[i]/1000,100,color=cmap(i),label='z=%sm'%z_plt[i],zorder=0)

        plt.legend(fontsize=fs-9)

        plt.xlabel(r'Temperature ($\degree$C)',fontsize=fs)
        plt.ylabel(r'Resistivity (k$\Omega$m)',fontsize=fs)

        ax.tick_params(axis='both', which='major', labelsize=fs-2)

        T_th = -0.00 

        # fit T>0 and T<0

        # frozen 

        px_f = T_plt[T_plt<T_th] 
        py_f = R_plt[T_plt<T_th]

        # unfrozen 

        px_uf = T_plt[T_plt>T_th]
        py_uf = R_plt[T_plt>T_th]

        coeff1 = np.poly1d(np.polyfit(px_uf,py_uf, 1)) # unfrozen
        coeff2 = np.poly1d(np.polyfit(px_f,py_f, 1))

        a,b = list(coeff1)
        c,d = list(coeff2)

        # find intersection point of two lines

        xth = (d-b)/(a-c)

        xn = np.linspace(xth,max(T_plt))
        p_uf = np.poly1d(coeff1)
        p_f = np.poly1d(coeff2)

        yth = p_uf(xth)

        # plot lines

        pad = 0.5
        plt.plot(np.linspace(min(T_plt)-pad,xth),p_f(np.linspace(min(T_plt)-pad,xth))/1000,'k--')
        plt.plot(np.linspace(xth,max(T_plt)+pad),p_uf(np.linspace(xth,max(T_plt)+pad))/1000,'k:')

        plt.plot(xth,yth/1000,'k*',markersize=10,)

        plt.text(xth+0.2,yth/1000+0.5,'(%.2f,%.1f)'%(xth,yth/1000),fontsize=fs-2)

        T_plt_all.append(T_plt)
        R_plt_all.append(R_plt)
        p_f_all.append(p_f)
        p_uf_all.append(p_uf)
        xth_all.append(xth)
        yth_all.append(yth)
        
        
        if j in [1, 4, 7]:


            cs = ax1.tricontour(
                np.array(mgr.paraDomain.cellCenters()).T[0],
                np.array(mgr.paraDomain.cellCenters()).T[1],
                mgr.model,
                levels=[yth],
                colors='k',
                linewidth=3,
                alpha=1,
                zorder=3          
                  )   

        else:

            cs = ax1.tricontour(
                np.array(mgr.paraDomain.cellCenters()).T[0],
                np.array(mgr.paraDomain.cellCenters()).T[1],
                mgr.model,
                levels=[yth],
                colors='blueviolet',
                linewidth=3,
                alpha=1,
                zorder=2
                  ) 


#         for i, collection in enumerate(cs.collections):
#             paths = collection.get_paths()
#             for path in paths:
#                 v = path.vertices
#                 contours.append(v)   # each v is an (N, 2) array of x,y points
                
        for collection in cs.collections:
            for path in collection.get_paths():
                contours_temp.append(path.vertices.copy())      

#         plt.close(fig1)
#         plt.close(fig2)
        contours.append(contours_temp)
    
        fig1.savefig('inverted results/belch uncertainty/lam'+str(lam[j])+'m'+str(mstart_mult[j])+'err'+str(err_rel[j])+'.png',format='png',dpi=dpi,bbox_inches='tight',facecolor='w')

    return T_plt_all,R_plt_all,p_f_all,p_uf_all,xth_all,yth_all,mgr,contours

# %%
T_belch,R_belch,p_f_belch,p_uf_belch,x_th_belch,y_th_belch,mgr_belch,contours_belch = generate_rho_T(
    pn = 'formatted ert data/summer 2023/',
    fn = '20230903 BELC W160.txt',
    pn_bh = 'borehole data/Belch_01_09.xlsx',
    x_bh = 118,
    depth_bh = 5.35,
    sensorids = None,
    lam=lam,
    mstart_mult=mstart_mult,
    err_rel=err_rel
    
)
# Out:
# 09/04/26 - 15:14:35 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 41): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:14:36 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:14:36 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:14:36 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:14:36 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:14:36 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:14:36 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:14:36 - pyGIMLi - INFO - Homogeneous starting model set to: 4575.832329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:266: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 09/04/26 - 15:14:42 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 42): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:14:42 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:14:42 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:14:42 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:14:42 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:14:42 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:14:42 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:14:42 - pyGIMLi - INFO - Homogeneous starting model set to: 4575.832329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:253: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 09/04/26 - 15:14:47 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 43): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:14:47 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:14:47 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:14:47 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:14:47 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:14:47 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:14:47 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:14:47 - pyGIMLi - INFO - Homogeneous starting model set to: 4575.832329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:266: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 09/04/26 - 15:14:53 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 44): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:14:53 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:14:53 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:14:53 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:14:53 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:14:53 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:14:53 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:14:53 - pyGIMLi - INFO - Homogeneous starting model set to: 4575.832329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:266: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 09/04/26 - 15:15:00 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 45): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:15:00 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:15:00 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:15:00 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:15:00 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:15:00 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:15:00 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:15:00 - pyGIMLi - INFO - Homogeneous starting model set to: 4575.832329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:253: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 09/04/26 - 15:15:06 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 46): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:15:06 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:15:06 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:15:06 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:15:06 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:15:06 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:15:06 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:15:06 - pyGIMLi - INFO - Homogeneous starting model set to: 4575.832329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:266: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 09/04/26 - 15:15:10 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 47): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:15:10 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:15:10 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:15:10 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:15:10 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:15:10 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:15:10 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:15:10 - pyGIMLi - INFO - Homogeneous starting model set to: 457.5832329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:266: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 09/04/26 - 15:15:17 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 48): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:15:17 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:15:17 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:15:17 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:15:17 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:15:17 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:15:17 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:15:17 - pyGIMLi - INFO - Homogeneous starting model set to: 4575.832329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:253: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(
# 09/04/26 - 15:15:22 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 49): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:15:22 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:15:22 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:15:22 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:15:22 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:15:22 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:15:22 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:15:23 - pyGIMLi - INFO - Homogeneous starting model set to: 45758.32329283695
# /var/folders/5z/g4c125y952l233l_4lb9yt6c0000gp/T/ipykernel_8769/3720059618.py:266: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cs = ax1.tricontour(

# %%
j=1

pn = 'formatted ert data/summer 2023/'
fn = '20230903 BELC W160.txt'
pn_bh = 'borehole data/Belch_01_09.xlsx'
x_bh = 118
depth_bh = 5.35
sensorids = None

data_raw = ert.load(pn+fn) 

# calculate geometric factor and apparent resistivity if not already in data file

if data_raw.haveData('k')==False:
    data_raw['k'] = ert.createGeometricFactors(data_raw,numerical=True) # include topo in k calculation

if data_raw.haveData('rhoa')==False:
    if data_raw.haveData('r')==False:
        data_raw['r'] = data_raw['u']/data_raw['i']
    data_raw['rhoa'] = data_raw['r']*data_raw['k'] 

# some datasets had problematic cables. if so, remove those data points

if sensorids is not None:
    data_raw.removeSensorIdx(sensorids)

mgr = ert.ERTManager(data_raw)

# inversion parameters

mgr.inv.inv.setBlockyModel(True)

data_raw['err'] = ert.estimateError(
data_raw, 
absoluteError=0.001, 
relativeError=err_rel[j] # % noise
)

# run inversion

mod = mgr.invert(
    data_raw,
    lam=lam[j],
    startModel=np.mean(data_raw['rhoa'])*mstart_mult[j],
#             zWeight=0.5
#             area=2,
#             verbose=True
)

# getting chi2, rms error

chi2 = mgr.inv.inv.getChi2()
rms = np.sqrt(np.mean(((data_raw['rhoa']-mgr.inv.response)/data_raw['rhoa'])**2))*100
# Out:
# 09/04/26 - 15:15:30 - pyGIMLi - INFO - Cache /Users/teddiherringnew/opt/miniconda3/envs/idgsp-mc/lib/python3.9/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (2.1s x 50): /Users/teddiherringnew/Library/Caches/pygimli/3077484105639835687
# 09/04/26 - 15:15:30 - pyGIMLi - INFO - Found 2 regions.
# 09/04/26 - 15:15:30 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 09/04/26 - 15:15:30 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 09/04/26 - 15:15:30 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 09/04/26 - 15:15:30 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/04/26 - 15:15:30 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/04/26 - 15:15:30 - pyGIMLi - INFO - Homogeneous starting model set to: 4575.832329283695

# %%
# plot results

fig1, ax1 = plt.subplots(1,1,figsize=[15,5])

ax, cBar = mgr.showResult(
   mod,
    ax=ax1,
    cMap='turbo_r',
    coverage=mgr.coverage(),
    cMin=100,
    cMax=15000,
    orientation='vertical',
)

# colorbar

cBar.set_label('')
cBar.ax.tick_params(labelsize=fs-4) 
cBar.ax.set_title(r'Resistivity ($\Omega$m)'+ '\n',fontsize=fs,rotation=270, y=-0.06,x=5)

# get axis limits and trim figure automatically

Ex = np.array(data_raw.sensors()).T[0]
Ey = np.array(data_raw.sensors()).T[1]
xmin = min(Ex)
xmax = max(Ex)
ymin = mgr.paraDomain.yMin()
ymax = mgr.paraDomain.yMax()
trim_ymin = ymin + (ymax-ymin)/2
ax1.set_ylim([trim_ymin,ymax+abs(ymax-ymin)*0.07])
ax1.set_xlim([xmin,xmax])

# figure details - electrodes, rms error, axis labels, borehole location

# ax1.plot(Ex,Ey,'ko')
txt = ax1.text(xmin+(xmax-xmin)*0.02,trim_ymin+(ymax-trim_ymin)*0.1,'RMSE=%.1f%%'%(rms),color='k',fontsize=fs)
#         txt.set_path_effects([PathEffects.withStroke(linewidth=3, foreground='k')])
ax1.tick_params(axis='both', labelsize=fs-4)
ax1.set_xlabel('X (m)',fontsize=fs)
ax1.set_ylabel('Z (m)',fontsize=fs)
# ax1.plot([x_bh,x_bh],[Ey[Ex==x_bh]-depth_bh,Ey[Ex==x_bh]],color='w',linewidth=5,zorder=4)


for i in range(len(contours_belch)):
    for j in range(len(contours_belch[i])):
        if i in [1, 4, 7]:
            ax1.plot(contours_belch[i][j][:, 0],contours_belch[i][j][:, 1], color='k',linestyle='-',linewidth=3,alpha=1,zorder=3)
        else:
            ax1.plot(contours_belch[i][j][:, 0],contours_belch[i][j][:, 1], color='blueviolet',linestyle='-',linewidth=3,alpha=0.6,zorder=2)

xt = np.hstack([-1,Ex,160])
yt = np.hstack([77,Ey+0.2,80])
from matplotlib.patches import Polygon

P= Polygon(np.array([xt,yt]).T, facecolor = 'w',edgecolor='w',linewidth=1,zorder=3) 
ax1.add_patch(P)

# for k in range(20,len(ft_x)):
#     ax1.plot(ft_x[k],Ey[np.where(Ex==ft_x[k])[0]]-ft_z[k]/100,marker='.',color='deepskyblue',markersize=8,zorder=4)
#     ax1.plot(ft_x[k],Ey[np.where(Ex==ft_x[k])[0]]-ft_z[k]/100,marker='.',color='k',markersize=12,zorder=3)

            
            
# fig1.savefig('inverted results/belch uncertainty/summary.png',format='png',dpi=dpi,bbox_inches='tight',facecolor='w')

# %%
y_th_belch
# Out:
# [766.0755035492277,
#  877.2538087292259,
#  1033.252477769935,
#  738.6439000570441,
#  877.3231459677739,
#  1077.8176235570431,
#  883.38273421784,
#  877.3673746453488,
#  934.3859168401128]

# %%
min(y_th_belch)
# Out:
# 738.6439000570441

# %%
max(y_th_belch)
# Out:
# 1077.8176235570431

# %%
mgr.inv.inv.setBlockyModel??
